# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('bodyfat.csv')
df.head()
# Out:
#    Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  Thigh  \
# 0   1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5   59.0
# 1   1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7   58.7
# 2   1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2   59.6
# 3   1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2   60.1
# 4   1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9   63.2
#
#    Knee  Ankle  Biceps  Forearm  Wrist
# 0  37.3   21.9    32.0     27.4   17.1
# 1  37.3   23.4    30.5     28.9   18.2
# 2  38.9   24.0    28.8     25.2   16.6
# 3  37.3   22.8    32.4     29.4   18.2
# 4  42.2   24.0    32.2     27.7   17.7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Density  252 non-null    float64
#  1   BodyFat  252 non-null    float64
#  2   Age      252 non-null    int64
#  3   Weight   252 non-null    float64
#  4   Height   252 non-null    float64
#  5   Neck     252 non-null    float64
#  6   Chest    252 non-null    float64
#  7   Abdomen  252 non-null    float64
#  8   Hip      252 non-null    float64
#  9   Thigh    252 non-null    float64
#  10  Knee     252 non-null    float64
#  11  Ankle    252 non-null    float64
#  12  Biceps   252 non-null    float64
#  13  Forearm  252 non-null    float64
#  14  Wrist    252 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 29.7 KB

# %%
def plotdistplots(col):
    plt.figure(figsize=(12,5))
    sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
    sn.distplot(df[col], color='red', hist=False, label=col)
    plt.legend()
    plt.show()

cols = list(df.columns)
for i in cols:
    print(f'Distribution plots for {i} feature is shown ↓')
    plotdistplots(i)
    print("-"*100)
# Out:
# Distribution plots for Density feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for BodyFat feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Age feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Weight feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Height feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Neck feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Chest feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Abdomen feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Hip feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Thigh feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Knee feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Ankle feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Biceps feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Forearm feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------
# Distribution plots for Wrist feature is shown ↓
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df['BodyFat'], color='magenta', hist=False, label='Bodyfat')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\454856711.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(df[col], color='red', hist=False, label=col)
# ----------------------------------------------------------------------------------------------------

# %%
import scipy.stats as stats

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

def drawplots(df, col):
    plt.figure(figsize=(15, 7))

    plt.subplot(1, 3, 1)
    plt.hist(df[col], color='magenta')

    plt.subplot(1, 3, 2)
    stats.probplot(df[col], dist='norm', plot=plt)

    plt.subplot(1, 3, 3)
    sn.boxplot(df[col], color='magenta')

    plt.show()

cols = list(df.columns)
for i in range(len(cols)):
    print(f'Distribution plots for the feature {cols[i]} are shown ↓')
    drawplots(df, cols[i])
    print("=" * 100)
# Out:
# Distribution plots for the feature Density are shown ↓
# ====================================================================================================
# Distribution plots for the feature BodyFat are shown ↓
# ====================================================================================================
# Distribution plots for the feature Age are shown ↓
# ====================================================================================================
# Distribution plots for the feature Weight are shown ↓
# ====================================================================================================
# Distribution plots for the feature Height are shown ↓
# ====================================================================================================
# Distribution plots for the feature Neck are shown ↓
# ====================================================================================================
# Distribution plots for the feature Chest are shown ↓
# ====================================================================================================
# Distribution plots for the feature Abdomen are shown ↓
# ====================================================================================================
# Distribution plots for the feature Hip are shown ↓
# ====================================================================================================
# Distribution plots for the feature Thigh are shown ↓
# ====================================================================================================
# Distribution plots for the feature Knee are shown ↓
# ====================================================================================================
# Distribution plots for the feature Ankle are shown ↓
# ====================================================================================================
# Distribution plots for the feature Biceps are shown ↓
# ====================================================================================================
# Distribution plots for the feature Forearm are shown ↓
# ====================================================================================================
# Distribution plots for the feature Wrist are shown ↓
# ====================================================================================================

# %%
upperlimit = []
lowerlimit = []

for i in df.columns:
    upperlimit.append(df[i].mean() + (df[i].std() * 4))
    lowerlimit.append(df[i].mean() - (df[i].std() * 4))

# %%
cols = list(df.columns)
outliers = pd.DataFrame()

j = 0  # Initialize j before the loop
for i in range(len(cols)):
    temp = df.loc[(df[cols[i]] > upperlimit[i]) | (df[cols[i]] < lowerlimit[i])]
    j += 1  # Increment j within the loop

# %%
temp
# Out:
# Empty DataFrame
# Columns: [Density, BodyFat, Age, Weight, Height, Neck, Chest, Abdomen, Hip, Thigh, Knee, Ankle, Biceps, Forearm, Wrist]
# Index: []

# %%
data = df.copy()
test = data['BodyFat']
train = data.drop(['BodyFat'],axis=1)

# %%
from sklearn.ensemble import ExtraTreesRegressor
er = ExtraTreesRegressor()
er.fit(train,test)
# Out:
# ExtraTreesRegressor()

# %%
series = pd.Series(er.feature_importances_,index=train.columns)
series.nlargest(5).plot(kind = 'barh',color = 'green')
# Out:
# <Axes: >

# %%
data
# Out:
#      Density  BodyFat  Age  Weight  Height  Neck  Chest  Abdomen    Hip  \
# 0     1.0708     12.3   23  154.25   67.75  36.2   93.1     85.2   94.5
# 1     1.0853      6.1   22  173.25   72.25  38.5   93.6     83.0   98.7
# 2     1.0414     25.3   22  154.00   66.25  34.0   95.8     87.9   99.2
# 3     1.0751     10.4   26  184.75   72.25  37.4  101.8     86.4  101.2
# 4     1.0340     28.7   24  184.25   71.25  34.4   97.3    100.0  101.9
# ..       ...      ...  ...     ...     ...   ...    ...      ...    ...
# 247   1.0736     11.0   70  134.25   67.00  34.9   89.2     83.6   88.8
# 248   1.0236     33.6   72  201.00   69.75  40.9  108.5    105.0  104.5
# 249   1.0328     29.3   72  186.75   66.00  38.9  111.1    111.5  101.7
# 250   1.0399     26.0   72  190.75   70.50  38.9  108.3    101.3   97.8
# 251   1.0271     31.9   74  207.50   70.00  40.8  112.4    108.5  107.1
#
#      Thigh  Knee  Ankle  Biceps  Forearm  Wrist
# 0     59.0  37.3   21.9    32.0     27.4   17.1
# 1     58.7  37.3   23.4    30.5     28.9   18.2
# 2     59.6  38.9   24.0    28.8     25.2   16.6
# 3     60.1  37.3   22.8    32.4     29.4   18.2
# 4     63.2  42.2   24.0    32.2     27.7   17.7
# ..     ...   ...    ...     ...      ...    ...
# 247   49.6  34.8   21.5    25.6     25.7   18.5
# 248   59.6  40.8   23.2    35.2     28.6   20.1
# 249   60.3  37.3   21.5    31.3     27.2   18.0
# 250   56.0  41.6   22.7    30.5     29.4   19.8
# 251   59.3  42.2   24.6    33.7     30.0   20.9
#
# [252 rows x 15 columns]

# %%
plt.figure(figsize=(15,7))
sn.heatmap(df.corr(),annot=True,cmap='plasma')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#           Density   BodyFat       Age    Weight    Height      Neck     Chest  \
# Density  1.000000 -0.987782 -0.277637 -0.594062  0.097881 -0.472966 -0.682599
# BodyFat -0.987782  1.000000  0.291458  0.612414 -0.089495  0.490592  0.702620
# Age     -0.277637  0.291458  1.000000 -0.012746 -0.171645  0.113505  0.176450
# Weight  -0.594062  0.612414 -0.012746  1.000000  0.308279  0.830716  0.894191
# Height   0.097881 -0.089495 -0.171645  0.308279  1.000000  0.253710  0.134892
# Neck    -0.472966  0.490592  0.113505  0.830716  0.253710  1.000000  0.784835
# Chest   -0.682599  0.702620  0.176450  0.894191  0.134892  0.784835  1.000000
# Abdomen -0.798955  0.813432  0.230409  0.887995  0.087813  0.754077  0.915828
# Hip     -0.609331  0.625201 -0.050332  0.940884  0.170394  0.734958  0.829420
# Thigh   -0.553091  0.559608 -0.200096  0.868694  0.148436  0.695697  0.729859
# Knee    -0.495040  0.508665  0.017516  0.853167  0.286053  0.672405  0.719496
# Ankle   -0.264890  0.265970 -0.105058  0.613685  0.264744  0.477892  0.482988
# Biceps  -0.487109  0.493271 -0.041162  0.800416  0.207816  0.731146  0.727907
# Forearm -0.351648  0.361387 -0.085056  0.630301  0.228649  0.623660  0.580173
# Wrist   -0.325716  0.346575  0.213531  0.729775  0.322065  0.744826  0.660162
#
#           Abdomen       Hip     Thigh      Knee     Ankle    Biceps   Forearm  \
# Density -0.798955 -0.609331 -0.553091 -0.495040 -0.264890 -0.487109 -0.351648
# BodyFat  0.813432  0.625201  0.559608  0.508665  0.265970  0.493271  0.361387
# Age      0.230409 -0.050332 -0.200096  0.017516 -0.105058 -0.041162 -0.085056
# Weight   0.887995  0.940884  0.868694  0.853167  0.613685  0.800416  0.630301
# Height   0.087813  0.170394  0.148436  0.286053  0.264744  0.207816  0.228649
# Neck     0.754077  0.734958  0.695697  0.672405  0.477892  0.731146  0.623660
# Chest    0.915828  0.829420  0.729859  0.719496  0.482988  0.727907  0.580173
# Abdomen  1.000000  0.874066  0.766624  0.737179  0.453223  0.684983  0.503316
# Hip      0.874066  1.000000  0.896410  0.823473  0.558387  0.739273  0.545014
# Thigh    0.766624  0.896410  1.000000  0.799170  0.539797  0.761477  0.566842
# Knee     0.737179  0.823473  0.799170  1.000000  0.611608  0.678709  0.555898
# Ankle    0.453223  0.558387  0.539797  0.611608  1.000000  0.484855  0.419050
# Biceps   0.684983  0.739273  0.761477  0.678709  0.484855  1.000000  0.678255
# Forearm  0.503316  0.545014  0.566842  0.555898  0.419050  0.678255  1.000000
# Wrist    0.619832  0.630090  0.558685  0.664507  0.566195  0.632126  0.585588
#
#             Wrist
# Density -0.325716
# BodyFat  0.346575
# Age      0.213531
# Weight   0.729775
# Height   0.322065
# Neck     0.744826
# Chest    0.660162
# Abdomen  0.619832
# Hip      0.630090
# Thigh    0.558685
# Knee     0.664507
# Ankle    0.566195
# Biceps   0.632126
# Forearm  0.585588
# Wrist    1.000000

# %%
def correlation(df, threshold):
    colcor = set()
    cormat = df.corr()
    for i in range(len(cormat)):  
        for j in range(i):
            if abs(cormat.iloc[i][j]) > threshold:
                colname = cormat.columns[i]
                colcor.add(colname)
    return colcor  # corrected typo: changed color to colcor

ans = correlation(train, threshold=0.85)
ans
# Out:
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\790509540.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(cormat.iloc[i][j]) > threshold:
# {'Abdomen', 'Chest', 'Hip', 'Knee', 'Thigh'}

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
temp = data[list(data.columns)]
temp.shape
# Out:
# (252, 15)

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

temp = data[list(data.columns)]
info = pd.DataFrame()
info['VIF'] = [variance_inflation_factor(temp.values, i) for i in range(temp.shape[1])]
info['Column'] = temp.columns
info
# Out:
#             VIF   Column
# 0   3695.622377  Density
# 1     33.845429  BodyFat
# 2     31.376101      Age
# 3   1238.097164   Weight
# 4    613.410514   Height
# 5   1081.965633     Neck
# 6   1374.457425    Chest
# 7   1332.624257  Abdomen
# 8   2933.636131      Hip
# 9   1017.257501    Thigh
# 10  1187.890413     Knee
# 11   356.293529    Ankle
# 12   419.391664   Biceps
# 13   454.571766  Forearm
# 14  1349.973920    Wrist

# %%
cols1 = list(series.nlargest(5).index)
cols2 = list(plotdata.nlargest(5, columns='column1').index)  
cols1, cols2
# Out:
# (['Density', 'Abdomen', 'Chest', 'Weight', 'Hip'], [4, 3, 2, 1, 0])

# %%
totrain = train[cols1]
totrain.head()
# Out:
#    Density  Abdomen  Chest  Weight    Hip
# 0   1.0708     85.2   93.1  154.25   94.5
# 1   1.0853     83.0   93.6  173.25   98.7
# 2   1.0414     87.9   95.8  154.00   99.2
# 3   1.0751     86.4  101.8  184.75  101.2
# 4   1.0340    100.0   97.3  184.25  101.9

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn import metrics
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression,Lasso,Ridge

# %%
X_train, X_test, y_train, y_test = train_test_split(totrain,test,test_size=0.2)
X_train.shape,X_test.shape
# Out:
# ((201, 5), (51, 5))

# %%
reg = DecisionTreeRegressor()
reg.fit(X_train,y_train)
plt.figure(figsize=(15,7))
tree.plot_tree(reg,filled=True)
# Out:
# [Text(0.4953261462882096, 0.9545454545454546, 'x[0] <= 1.056\nsquared_error = 69.897\nsamples = 201\nvalue = 19.7'),
#  Text(0.2076282751091703, 0.8636363636363636, 'x[0] <= 1.036\nsquared_error = 26.424\nsamples = 110\nvalue = 25.915'),
#  Text(0.055676855895196505, 0.7727272727272727, 'x[0] <= 1.017\nsquared_error = 14.52\nsamples = 35\nvalue = 32.051'),
#  Text(0.013100436681222707, 0.6818181818181818, 'x[1] <= 117.9\nsquared_error = 16.347\nsamples = 3\nvalue = 41.9'),
#  Text(0.008733624454148471, 0.5909090909090909, 'x[1] <= 113.4\nsquared_error = 1.0\nsamples = 2\nvalue = 39.1'),
#  Text(0.004366812227074236, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 40.1'),
#  Text(0.013100436681222707, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 38.1'),
#  Text(0.017467248908296942, 0.5909090909090909, 'squared_error = 0.0\nsamples = 1\nvalue = 47.5'),
#  Text(0.0982532751091703, 0.6818181818181818, 'x[0] <= 1.029\nsquared_error = 4.403\nsamples = 32\nvalue = 31.128'),
#  Text(0.04694323144104803, 0.5909090909090909, 'x[0] <= 1.024\nsquared_error = 1.656\nsamples = 16\nvalue = 32.931'),
#  Text(0.021834061135371178, 0.5, 'x[3] <= 212.0\nsquared_error = 0.314\nsamples = 5\nvalue = 34.62'),
#  Text(0.017467248908296942, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 33.6'),
#  Text(0.026200873362445413, 0.4090909090909091, 'x[0] <= 1.021\nsquared_error = 0.067\nsamples = 4\nvalue = 34.875'),
#  Text(0.017467248908296942, 0.3181818181818182, 'x[2] <= 127.9\nsquared_error = 0.01\nsamples = 2\nvalue = 35.1'),
#  Text(0.013100436681222707, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 35.0'),
#  Text(0.021834061135371178, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 35.2'),
#  Text(0.034934497816593885, 0.3181818181818182, 'x[1] <= 120.05\nsquared_error = 0.023\nsamples = 2\nvalue = 34.65'),
#  Text(0.03056768558951965, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.8'),
#  Text(0.039301310043668124, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 34.5'),
#  Text(0.07205240174672489, 0.5, 'x[0] <= 1.027\nsquared_error = 0.38\nsamples = 11\nvalue = 32.164'),
#  Text(0.0611353711790393, 0.4090909090909091, 'x[0] <= 1.025\nsquared_error = 0.045\nsamples = 6\nvalue = 32.683'),
#  Text(0.05240174672489083, 0.3181818181818182, 'x[0] <= 1.025\nsquared_error = 0.002\nsamples = 3\nvalue = 32.867'),
#  Text(0.048034934497816595, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 32.9'),
#  Text(0.056768558951965066, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.8'),
#  Text(0.06986899563318777, 0.3181818181818182, 'x[2] <= 110.05\nsquared_error = 0.02\nsamples = 3\nvalue = 32.5'),
#  Text(0.06550218340611354, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 32.3'),
#  Text(0.07423580786026202, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 32.6'),
#  Text(0.08296943231441048, 0.4090909090909091, 'x[0] <= 1.027\nsquared_error = 0.07\nsamples = 5\nvalue = 31.54'),
#  Text(0.07860262008733625, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 32.0'),
#  Text(0.08733624454148471, 0.3181818181818182, 'x[0] <= 1.029\nsquared_error = 0.022\nsamples = 4\nvalue = 31.425'),
#  Text(0.08296943231441048, 0.22727272727272727, 'x[0] <= 1.028\nsquared_error = 0.007\nsamples = 3\nvalue = 31.5'),
#  Text(0.07860262008733625, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 31.6'),
#  Text(0.08733624454148471, 0.13636363636363635, 'x[4] <= 97.05\nsquared_error = 0.003\nsamples = 2\nvalue = 31.45'),
#  Text(0.08296943231441048, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 31.5'),
#  Text(0.09170305676855896, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 31.4'),
#  Text(0.09170305676855896, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 31.2'),
#  Text(0.14956331877729256, 0.5909090909090909, 'x[0] <= 1.033\nsquared_error = 0.648\nsamples = 16\nvalue = 29.325'),
#  Text(0.12882096069868995, 0.5, 'x[0] <= 1.032\nsquared_error = 0.187\nsamples = 9\nvalue = 29.933'),
#  Text(0.11353711790393013, 0.4090909090909091, 'x[0] <= 1.031\nsquared_error = 0.085\nsamples = 6\nvalue = 30.183'),
#  Text(0.10480349344978165, 0.3181818181818182, 'x[3] <= 213.75\nsquared_error = 0.023\nsamples = 2\nvalue = 30.55'),
#  Text(0.10043668122270742, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 30.7'),
#  Text(0.1091703056768559, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 30.4'),
#  Text(0.1222707423580786, 0.3181818181818182, 'x[0] <= 1.031\nsquared_error = 0.015\nsamples = 4\nvalue = 30.0'),
#  Text(0.11790393013100436, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 30.2'),
#  Text(0.12663755458515283, 0.22727272727272727, 'x[1] <= 100.4\nsquared_error = 0.002\nsamples = 3\nvalue = 29.933'),
#  Text(0.1222707423580786, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 30.0'),
#  Text(0.13100436681222707, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 29.9'),
#  Text(0.14410480349344978, 0.4090909090909091, 'x[4] <= 103.95\nsquared_error = 0.016\nsamples = 3\nvalue = 29.433'),
#  Text(0.13973799126637554, 0.3181818181818182, 'x[3] <= 187.25\nsquared_error = 0.002\nsamples = 2\nvalue = 29.35'),
#  Text(0.13537117903930132, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 29.3'),
#  Text(0.14410480349344978, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 29.4'),
#  Text(0.14847161572052403, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 29.6'),
#  Text(0.1703056768558952, 0.5, 'x[0] <= 1.034\nsquared_error = 0.154\nsamples = 7\nvalue = 28.543'),
#  Text(0.1615720524017467, 0.4090909090909091, 'x[0] <= 1.034\nsquared_error = 0.023\nsamples = 4\nvalue = 28.85'),
#  Text(0.1572052401746725, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 29.0'),
#  Text(0.16593886462882096, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.7'),
#  Text(0.17903930131004367, 0.4090909090909091, 'x[2] <= 106.8\nsquared_error = 0.036\nsamples = 3\nvalue = 28.133'),
#  Text(0.17467248908296942, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 28.4'),
#  Text(0.18340611353711792, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 28.0'),
#  Text(0.35957969432314413, 0.7727272727272727, 'x[0] <= 1.047\nsquared_error = 6.21\nsamples = 75\nvalue = 23.052'),
#  Text(0.26582969432314413, 0.6818181818181818, 'x[0] <= 1.041\nsquared_error = 1.353\nsamples = 34\nvalue = 25.482'),
#  Text(0.22816593886462883, 0.5909090909090909, 'x[0] <= 1.039\nsquared_error = 0.297\nsamples = 15\nvalue = 26.587'),
#  Text(0.21179039301310043, 0.5, 'x[0] <= 1.038\nsquared_error = 0.058\nsamples = 9\nvalue = 27.0'),
#  Text(0.20087336244541484, 0.4090909090909091, 'x[3] <= 201.125\nsquared_error = 0.016\nsamples = 6\nvalue = 27.15'),
#  Text(0.19213973799126638, 0.3181818181818182, 'x[2] <= 103.2\nsquared_error = 0.002\nsamples = 3\nvalue = 27.033'),
#  Text(0.18777292576419213, 0.22727272727272727, 'x[0] <= 1.038\nsquared_error = 0.0\nsamples = 2\nvalue = 27.0'),
#  Text(0.18340611353711792, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.19213973799126638, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(0.1965065502183406, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.1'),
#  Text(0.2096069868995633, 0.3181818181818182, 'x[0] <= 1.037\nsquared_error = 0.002\nsamples = 3\nvalue = 27.267'),
#  Text(0.2052401746724891, 0.22727272727272727, 'x[3] <= 218.95\nsquared_error = 0.0\nsamples = 2\nvalue = 27.3'),
#  Text(0.20087336244541484, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.2096069868995633, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 27.3'),
#  Text(0.21397379912663755, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 27.2'),
#  Text(0.22270742358078602, 0.4090909090909091, 'x[3] <= 156.0\nsquared_error = 0.007\nsamples = 3\nvalue = 26.7'),
#  Text(0.2183406113537118, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 26.8'),
#  Text(0.22707423580786026, 0.3181818181818182, 'x[0] <= 1.039\nsquared_error = 0.003\nsamples = 2\nvalue = 26.65'),
#  Text(0.22270742358078602, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.7'),
#  Text(0.2314410480349345, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 26.6'),
#  Text(0.2445414847161572, 0.5, 'x[0] <= 1.04\nsquared_error = 0.016\nsamples = 6\nvalue = 25.967'),
#  Text(0.24017467248908297, 0.4090909090909091, 'x[0] <= 1.04\nsquared_error = 0.003\nsamples = 4\nvalue = 26.05'),
#  Text(0.23580786026200873, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 26.1'),
#  Text(0.2445414847161572, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 26.0'),
#  Text(0.24890829694323144, 0.4090909090909091, 'squared_error = -0.0\nsamples = 2\nvalue = 25.8'),
#  Text(0.3034934497816594, 0.5909090909090909, 'x[0] <= 1.043\nsquared_error = 0.463\nsamples = 19\nvalue = 24.611'),
#  Text(0.2794759825327511, 0.5, 'x[0] <= 1.042\nsquared_error = 0.084\nsamples = 11\nvalue = 25.109'),
#  Text(0.26200873362445415, 0.4090909090909091, 'x[0] <= 1.041\nsquared_error = 0.01\nsamples = 7\nvalue = 25.314'),
#  Text(0.25327510917030566, 0.3181818181818182, 'x[2] <= 102.8\nsquared_error = 0.002\nsamples = 2\nvalue = 25.45'),
#  Text(0.24890829694323144, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 25.5'),
#  Text(0.2576419213973799, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 25.4'),
#  Text(0.27074235807860264, 0.3181818181818182, 'x[0] <= 1.041\nsquared_error = 0.002\nsamples = 5\nvalue = 25.26'),
#  Text(0.2663755458515284, 0.22727272727272727, 'x[1] <= 93.0\nsquared_error = 0.0\nsamples = 3\nvalue = 25.3'),
#  Text(0.26200873362445415, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 25.3'),
#  Text(0.27074235807860264, 0.13636363636363635, 'squared_error = -0.0\nsamples = 2\nvalue = 25.3'),
#  Text(0.27510917030567683, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 25.2'),
#  Text(0.29694323144104806, 0.4090909090909091, 'x[1] <= 98.25\nsquared_error = 0.012\nsamples = 4\nvalue = 24.75'),
#  Text(0.28820960698689957, 0.3181818181818182, 'x[4] <= 101.35\nsquared_error = 0.002\nsamples = 2\nvalue = 24.85'),
#  Text(0.2838427947598253, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.8'),
#  Text(0.2925764192139738, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 24.9'),
#  Text(0.3056768558951965, 0.3181818181818182, 'x[2] <= 105.75\nsquared_error = 0.003\nsamples = 2\nvalue = 24.65'),
#  Text(0.30131004366812225, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.6'),
#  Text(0.31004366812227074, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.7'),
#  Text(0.32751091703056767, 0.5, 'x[0] <= 1.045\nsquared_error = 0.172\nsamples = 8\nvalue = 23.925'),
#  Text(0.31877729257641924, 0.4090909090909091, 'x[0] <= 1.044\nsquared_error = 0.007\nsamples = 4\nvalue = 24.325'),
#  Text(0.314410480349345, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 24.4'),
#  Text(0.3231441048034934, 0.3181818181818182, 'x[1] <= 96.2\nsquared_error = 0.002\nsamples = 2\nvalue = 24.25'),
#  Text(0.31877729257641924, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.3'),
#  Text(0.32751091703056767, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 24.2'),
#  Text(0.33624454148471616, 0.4090909090909091, 'x[2] <= 103.15\nsquared_error = 0.017\nsamples = 4\nvalue = 23.525'),
#  Text(0.3318777292576419, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 23.3'),
#  Text(0.3406113537117904, 0.3181818181818182, 'squared_error = -0.0\nsamples = 3\nvalue = 23.6'),
#  Text(0.45332969432314413, 0.6818181818181818, 'x[0] <= 1.052\nsquared_error = 1.277\nsamples = 41\nvalue = 21.037'),
#  Text(0.41102620087336245, 0.5909090909090909, 'x[0] <= 1.049\nsquared_error = 0.356\nsamples = 23\nvalue = 21.904'),
#  Text(0.38209606986899564, 0.5, 'x[0] <= 1.048\nsquared_error = 0.082\nsamples = 12\nvalue = 22.408'),
#  Text(0.3624454148471616, 0.4090909090909091, 'x[0] <= 1.047\nsquared_error = 0.022\nsamples = 6\nvalue = 22.667'),
#  Text(0.34934497816593885, 0.3181818181818182, 'x[0] <= 1.047\nsquared_error = 0.007\nsamples = 3\nvalue = 22.8'),
#  Text(0.34497816593886466, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.9'),
#  Text(0.3537117903930131, 0.22727272727272727, 'x[2] <= 93.4\nsquared_error = 0.002\nsamples = 2\nvalue = 22.75'),
#  Text(0.34934497816593885, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.8'),
#  Text(0.35807860262008734, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.7'),
#  Text(0.37554585152838427, 0.3181818181818182, 'x[2] <= 105.15\nsquared_error = 0.002\nsamples = 3\nvalue = 22.533'),
#  Text(0.37117903930131, 0.22727272727272727, 'x[1] <= 92.55\nsquared_error = 0.0\nsamples = 2\nvalue = 22.5'),
#  Text(0.36681222707423583, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.37554585152838427, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 22.5'),
#  Text(0.3799126637554585, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 22.6'),
#  Text(0.4017467248908297, 0.4090909090909091, 'x[2] <= 101.65\nsquared_error = 0.009\nsamples = 6\nvalue = 22.15'),
#  Text(0.3930131004366812, 0.3181818181818182, 'x[0] <= 1.049\nsquared_error = 0.002\nsamples = 3\nvalue = 22.067'),
#  Text(0.388646288209607, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 22.1'),
#  Text(0.39737991266375544, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.0'),
#  Text(0.4104803493449782, 0.3181818181818182, 'x[1] <= 95.25\nsquared_error = 0.002\nsamples = 3\nvalue = 22.233'),
#  Text(0.40611353711790393, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 22.2'),
#  Text(0.4148471615720524, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 22.3'),
#  Text(0.43995633187772926, 0.5, 'x[0] <= 1.05\nsquared_error = 0.075\nsamples = 11\nvalue = 21.355'),
#  Text(0.42358078602620086, 0.4090909090909091, 'x[0] <= 1.05\nsquared_error = 0.028\nsamples = 5\nvalue = 21.6'),
#  Text(0.4192139737991266, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 21.8'),
#  Text(0.4279475982532751, 0.3181818181818182, 'x[4] <= 99.95\nsquared_error = 0.002\nsamples = 3\nvalue = 21.467'),
#  Text(0.42358078602620086, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 21.5'),
#  Text(0.43231441048034935, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.4'),
#  Text(0.45633187772925765, 0.4090909090909091, 'x[3] <= 199.375\nsquared_error = 0.022\nsamples = 6\nvalue = 21.15'),
#  Text(0.44541484716157204, 0.3181818181818182, 'x[4] <= 100.75\nsquared_error = 0.003\nsamples = 2\nvalue = 21.25'),
#  Text(0.4410480349344978, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.4497816593886463, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.4672489082969432, 0.3181818181818182, 'x[4] <= 108.05\nsquared_error = 0.025\nsamples = 4\nvalue = 21.1'),
#  Text(0.4585152838427948, 0.22727272727272727, 'x[3] <= 205.25\nsquared_error = 0.002\nsamples = 2\nvalue = 20.95'),
#  Text(0.45414847161572053, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.0'),
#  Text(0.462882096069869, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 20.9'),
#  Text(0.4759825327510917, 0.22727272727272727, 'x[3] <= 211.875\nsquared_error = 0.003\nsamples = 2\nvalue = 21.25'),
#  Text(0.47161572052401746, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.2'),
#  Text(0.48034934497816595, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 21.3'),
#  Text(0.49563318777292575, 0.5909090909090909, 'x[0] <= 1.053\nsquared_error = 0.263\nsamples = 18\nvalue = 19.928'),
#  Text(0.48034934497816595, 0.5, 'x[2] <= 97.9\nsquared_error = 0.02\nsamples = 10\nvalue = 20.36'),
#  Text(0.4759825327510917, 0.4090909090909091, 'squared_error = 0.0\nsamples = 2\nvalue = 20.1'),
#  Text(0.4847161572052402, 0.4090909090909091, 'x[0] <= 1.052\nsquared_error = 0.004\nsamples = 8\nvalue = 20.425'),
#  Text(0.48034934497816595, 0.3181818181818182, 'squared_error = 0.0\nsamples = 3\nvalue = 20.5'),
#  Text(0.4890829694323144, 0.3181818181818182, 'x[2] <= 107.8\nsquared_error = 0.002\nsamples = 5\nvalue = 20.38'),
#  Text(0.4847161572052402, 0.22727272727272727, 'squared_error = -0.0\nsamples = 4\nvalue = 20.4'),
#  Text(0.49344978165938863, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 20.3'),
#  Text(0.5109170305676856, 0.5, 'x[0] <= 1.054\nsquared_error = 0.041\nsamples = 8\nvalue = 19.388'),
#  Text(0.5021834061135371, 0.4090909090909091, 'x[4] <= 99.2\nsquared_error = 0.007\nsamples = 4\nvalue = 19.575'),
#  Text(0.4978165938864629, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 19.5'),
#  Text(0.5065502183406113, 0.3181818181818182, 'x[2] <= 102.3\nsquared_error = 0.002\nsamples = 2\nvalue = 19.65'),
#  Text(0.5021834061135371, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.7'),
#  Text(0.5109170305676856, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.6'),
#  Text(0.519650655021834, 0.4090909090909091, 'x[0] <= 1.055\nsquared_error = 0.005\nsamples = 4\nvalue = 19.2'),
#  Text(0.5152838427947598, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 19.3'),
#  Text(0.5240174672489083, 0.3181818181818182, 'x[0] <= 1.055\nsquared_error = 0.002\nsamples = 3\nvalue = 19.167'),
#  Text(0.519650655021834, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 19.2'),
#  Text(0.5283842794759825, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 19.1'),
#  Text(0.7830240174672489, 0.8636363636363636, 'x[0] <= 1.071\nsquared_error = 19.301\nsamples = 91\nvalue = 12.187'),
#  Text(0.6539301310043668, 0.7727272727272727, 'x[0] <= 1.063\nsquared_error = 4.197\nsamples = 48\nvalue = 15.565'),
#  Text(0.5971615720524017, 0.6818181818181818, 'x[0] <= 1.06\nsquared_error = 0.653\nsamples = 22\nvalue = 17.4'),
#  Text(0.5633187772925764, 0.5909090909090909, 'x[0] <= 1.058\nsquared_error = 0.196\nsamples = 14\nvalue = 17.914'),
#  Text(0.5458515283842795, 0.5, 'x[0] <= 1.056\nsquared_error = 0.057\nsamples = 7\nvalue = 18.3'),
#  Text(0.5414847161572053, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 18.8'),
#  Text(0.5502183406113537, 0.4090909090909091, 'x[2] <= 98.65\nsquared_error = 0.018\nsamples = 6\nvalue = 18.217'),
#  Text(0.5414847161572053, 0.3181818181818182, 'x[2] <= 95.45\nsquared_error = 0.003\nsamples = 2\nvalue = 18.05'),
#  Text(0.537117903930131, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.0'),
#  Text(0.5458515283842795, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 18.1'),
#  Text(0.5589519650655022, 0.3181818181818182, 'x[0] <= 1.057\nsquared_error = 0.005\nsamples = 4\nvalue = 18.3'),
#  Text(0.5545851528384279, 0.22727272727272727, 'x[0] <= 1.057\nsquared_error = 0.002\nsamples = 3\nvalue = 18.333'),
#  Text(0.5502183406113537, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 18.4'),
#  Text(0.5589519650655022, 0.13636363636363635, 'x[0] <= 1.057\nsquared_error = 0.0\nsamples = 2\nvalue = 18.3'),
#  Text(0.5545851528384279, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5633187772925764, 0.045454545454545456, 'squared_error = 0.0\nsamples = 1\nvalue = 18.3'),
#  Text(0.5633187772925764, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 18.2'),
#  Text(0.5807860262008734, 0.5, 'x[0] <= 1.059\nsquared_error = 0.036\nsamples = 7\nvalue = 17.529'),
#  Text(0.5720524017467249, 0.4090909090909091, 'x[0] <= 1.058\nsquared_error = 0.002\nsamples = 3\nvalue = 17.733'),
#  Text(0.5676855895196506, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 17.8'),
#  Text(0.5764192139737991, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 17.7'),
#  Text(0.5895196506550219, 0.4090909090909091, 'x[4] <= 96.9\nsquared_error = 0.007\nsamples = 4\nvalue = 17.375'),
#  Text(0.5851528384279476, 0.3181818181818182, 'x[4] <= 94.35\nsquared_error = 0.002\nsamples = 2\nvalue = 17.45'),
#  Text(0.5807860262008734, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.4'),
#  Text(0.5895196506550219, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 17.5'),
#  Text(0.5938864628820961, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 17.3'),
#  Text(0.631004366812227, 0.5909090909090909, 'x[0] <= 1.062\nsquared_error = 0.18\nsamples = 8\nvalue = 16.5'),
#  Text(0.6157205240174672, 0.5, 'x[0] <= 1.061\nsquared_error = 0.044\nsamples = 5\nvalue = 16.8'),
#  Text(0.6069868995633187, 0.4090909090909091, 'x[3] <= 172.0\nsquared_error = 0.002\nsamples = 3\nvalue = 16.967'),
#  Text(0.6026200873362445, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 17.0'),
#  Text(0.611353711790393, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 16.9'),
#  Text(0.6244541484716157, 0.4090909090909091, 'x[3] <= 190.75\nsquared_error = 0.003\nsamples = 2\nvalue = 16.55'),
#  Text(0.6200873362445415, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.5'),
#  Text(0.62882096069869, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.6'),
#  Text(0.6462882096069869, 0.5, 'x[1] <= 95.4\nsquared_error = 0.007\nsamples = 3\nvalue = 16.0'),
#  Text(0.6419213973799127, 0.4090909090909091, 'x[0] <= 1.062\nsquared_error = 0.003\nsamples = 2\nvalue = 15.95'),
#  Text(0.6375545851528385, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(0.6462882096069869, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 15.9'),
#  Text(0.6506550218340611, 0.4090909090909091, 'squared_error = -0.0\nsamples = 1\nvalue = 16.1'),
#  Text(0.7106986899563319, 0.6818181818181818, 'x[0] <= 1.067\nsquared_error = 1.934\nsamples = 26\nvalue = 14.012'),
#  Text(0.675764192139738, 0.5909090909090909, 'x[1] <= 81.85\nsquared_error = 1.166\nsamples = 12\nvalue = 15.192'),
#  Text(0.6637554585152838, 0.5, 'x[1] <= 79.1\nsquared_error = 2.102\nsamples = 2\nvalue = 17.05'),
#  Text(0.6593886462882096, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 15.6'),
#  Text(0.6681222707423581, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 18.5'),
#  Text(0.6877729257641921, 0.5, 'x[0] <= 1.066\nsquared_error = 0.15\nsamples = 10\nvalue = 14.82'),
#  Text(0.6768558951965066, 0.4090909090909091, 'x[0] <= 1.065\nsquared_error = 0.046\nsamples = 8\nvalue = 14.988'),
#  Text(0.6681222707423581, 0.3181818181818182, 'x[1] <= 86.2\nsquared_error = 0.016\nsamples = 3\nvalue = 15.233'),
#  Text(0.6637554585152838, 0.22727272727272727, 'x[2] <= 93.3\nsquared_error = 0.003\nsamples = 2\nvalue = 15.15'),
#  Text(0.6593886462882096, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 15.1'),
#  Text(0.6681222707423581, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 15.2'),
#  Text(0.6724890829694323, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 15.4'),
#  Text(0.6855895196506551, 0.3181818181818182, 'x[0] <= 1.065\nsquared_error = 0.006\nsamples = 5\nvalue = 14.84'),
#  Text(0.6812227074235808, 0.22727272727272727, 'squared_error = 0.0\nsamples = 3\nvalue = 14.9'),
#  Text(0.6899563318777293, 0.22727272727272727, 'x[2] <= 100.5\nsquared_error = 0.002\nsamples = 2\nvalue = 14.75'),
#  Text(0.6855895196506551, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.7'),
#  Text(0.6943231441048034, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 14.8'),
#  Text(0.6986899563318777, 0.4090909090909091, 'x[4] <= 96.8\nsquared_error = 0.003\nsamples = 2\nvalue = 14.15'),
#  Text(0.6943231441048034, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.2'),
#  Text(0.7030567685589519, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.1'),
#  Text(0.7456331877729258, 0.5909090909090909, 'x[0] <= 1.068\nsquared_error = 0.376\nsamples = 14\nvalue = 13.0'),
#  Text(0.7248908296943232, 0.5, 'x[4] <= 91.1\nsquared_error = 0.03\nsamples = 5\nvalue = 13.74'),
#  Text(0.7161572052401747, 0.4090909090909091, 'x[0] <= 1.068\nsquared_error = 0.002\nsamples = 2\nvalue = 13.55'),
#  Text(0.7117903930131004, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.6'),
#  Text(0.7205240174672489, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 13.5'),
#  Text(0.7336244541484717, 0.4090909090909091, 'x[3] <= 153.0\nsquared_error = 0.009\nsamples = 3\nvalue = 13.867'),
#  Text(0.7292576419213974, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(0.7379912663755459, 0.3181818181818182, 'x[0] <= 1.067\nsquared_error = 0.0\nsamples = 2\nvalue = 13.8'),
#  Text(0.7336244541484717, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.74235807860262, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.8'),
#  Text(0.7663755458515283, 0.5, 'x[0] <= 1.07\nsquared_error = 0.094\nsamples = 9\nvalue = 12.589'),
#  Text(0.7510917030567685, 0.4090909090909091, 'x[2] <= 93.5\nsquared_error = 0.007\nsamples = 3\nvalue = 13.0'),
#  Text(0.7467248908296943, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 13.1'),
#  Text(0.7554585152838428, 0.3181818181818182, 'x[0] <= 1.069\nsquared_error = 0.002\nsamples = 2\nvalue = 12.95'),
#  Text(0.7510917030567685, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 13.0'),
#  Text(0.759825327510917, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.9'),
#  Text(0.7816593886462883, 0.4090909090909091, 'x[0] <= 1.071\nsquared_error = 0.011\nsamples = 6\nvalue = 12.383'),
#  Text(0.7729257641921398, 0.3181818181818182, 'x[4] <= 92.15\nsquared_error = 0.003\nsamples = 4\nvalue = 12.45'),
#  Text(0.7685589519650655, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 12.5'),
#  Text(0.777292576419214, 0.22727272727272727, 'x[1] <= 85.65\nsquared_error = 0.0\nsamples = 2\nvalue = 12.4'),
#  Text(0.7729257641921398, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7816593886462883, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 12.4'),
#  Text(0.7903930131004366, 0.3181818181818182, 'x[3] <= 166.25\nsquared_error = 0.003\nsamples = 2\nvalue = 12.25'),
#  Text(0.7860262008733624, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.3'),
#  Text(0.7947598253275109, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 12.2'),
#  Text(0.912117903930131, 0.7727272727272727, 'x[0] <= 1.08\nsquared_error = 9.208\nsamples = 43\nvalue = 8.416'),
#  Text(0.8569868995633187, 0.6818181818181818, 'x[0] <= 1.076\nsquared_error = 1.334\nsamples = 24\nvalue = 10.129'),
#  Text(0.8296943231441049, 0.5909090909090909, 'x[0] <= 1.074\nsquared_error = 0.302\nsamples = 12\nvalue = 11.158'),
#  Text(0.8122270742358079, 0.5, 'x[3] <= 165.25\nsquared_error = 0.041\nsamples = 7\nvalue = 11.586'),
#  Text(0.8034934497816594, 0.4090909090909091, 'x[0] <= 1.073\nsquared_error = 0.007\nsamples = 4\nvalue = 11.425'),
#  Text(0.7991266375545851, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 11.5'),
#  Text(0.8078602620087336, 0.3181818181818182, 'x[4] <= 94.25\nsquared_error = 0.003\nsamples = 2\nvalue = 11.35'),
#  Text(0.8034934497816594, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.4'),
#  Text(0.8122270742358079, 0.22727272727272727, 'squared_error = -0.0\nsamples = 1\nvalue = 11.3'),
#  Text(0.8209606986899564, 0.4090909090909091, 'x[0] <= 1.072\nsquared_error = 0.007\nsamples = 3\nvalue = 11.8'),
#  Text(0.8165938864628821, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 11.9'),
#  Text(0.8253275109170306, 0.3181818181818182, 'x[2] <= 96.3\nsquared_error = 0.002\nsamples = 2\nvalue = 11.75'),
#  Text(0.8209606986899564, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.8'),
#  Text(0.8296943231441049, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 11.7'),
#  Text(0.8471615720524017, 0.5, 'x[0] <= 1.075\nsquared_error = 0.054\nsamples = 5\nvalue = 10.56'),
#  Text(0.8384279475982532, 0.4090909090909091, 'x[1] <= 85.4\nsquared_error = 0.009\nsamples = 3\nvalue = 10.733'),
#  Text(0.834061135371179, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 10.8'),
#  Text(0.8427947598253275, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 10.6'),
#  Text(0.8558951965065502, 0.4090909090909091, 'x[4] <= 99.75\nsquared_error = 0.01\nsamples = 2\nvalue = 10.3'),
#  Text(0.851528384279476, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 10.2'),
#  Text(0.8602620087336245, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 10.4'),
#  Text(0.8842794759825328, 0.5909090909090909, 'x[0] <= 1.078\nsquared_error = 0.247\nsamples = 12\nvalue = 9.1'),
#  Text(0.868995633187773, 0.5, 'x[0] <= 1.077\nsquared_error = 0.033\nsamples = 6\nvalue = 9.55'),
#  Text(0.8646288209606987, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 9.9'),
#  Text(0.8733624454148472, 0.4090909090909091, 'x[2] <= 96.55\nsquared_error = 0.01\nsamples = 5\nvalue = 9.48'),
#  Text(0.868995633187773, 0.3181818181818182, 'x[4] <= 92.5\nsquared_error = 0.0\nsamples = 3\nvalue = 9.4'),
#  Text(0.8646288209606987, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 9.4'),
#  Text(0.8733624454148472, 0.22727272727272727, 'squared_error = -0.0\nsamples = 2\nvalue = 9.4'),
#  Text(0.8777292576419214, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 9.6'),
#  Text(0.8995633187772926, 0.5, 'x[0] <= 1.079\nsquared_error = 0.056\nsamples = 6\nvalue = 8.65'),
#  Text(0.8908296943231441, 0.4090909090909091, 'x[4] <= 100.05\nsquared_error = 0.009\nsamples = 3\nvalue = 8.867'),
#  Text(0.8864628820960698, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 8.8'),
#  Text(0.8951965065502183, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 9.0'),
#  Text(0.9082969432314411, 0.4090909090909091, 'x[4] <= 97.8\nsquared_error = 0.009\nsamples = 3\nvalue = 8.433'),
#  Text(0.9039301310043668, 0.3181818181818182, 'squared_error = 0.0\nsamples = 2\nvalue = 8.5'),
#  Text(0.9126637554585153, 0.3181818181818182, 'squared_error = 0.0\nsamples = 1\nvalue = 8.3'),
#  Text(0.9672489082969432, 0.6818181818181818, 'x[4] <= 105.05\nsquared_error = 10.767\nsamples = 19\nvalue = 6.253'),
#  Text(0.962882096069869, 0.5909090909090909, 'x[0] <= 1.089\nsquared_error = 4.078\nsamples = 18\nvalue = 5.633'),
#  Text(0.9388646288209607, 0.5, 'x[0] <= 1.083\nsquared_error = 0.859\nsamples = 13\nvalue = 6.677'),
#  Text(0.925764192139738, 0.4090909090909091, 'x[0] <= 1.082\nsquared_error = 0.126\nsamples = 6\nvalue = 7.55'),
#  Text(0.9213973799126638, 0.3181818181818182, 'x[0] <= 1.081\nsquared_error = 0.037\nsamples = 4\nvalue = 7.775'),
#  Text(0.9126637554585153, 0.22727272727272727, 'x[4] <= 87.2\nsquared_error = 0.002\nsamples = 2\nvalue = 7.95'),
#  Text(0.9082969432314411, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.9'),
#  Text(0.9170305676855895, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 8.0'),
#  Text(0.9301310043668122, 0.22727272727272727, 'x[0] <= 1.082\nsquared_error = 0.01\nsamples = 2\nvalue = 7.6'),
#  Text(0.925764192139738, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.7'),
#  Text(0.9344978165938864, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 7.5'),
#  Text(0.9301310043668122, 0.3181818181818182, 'squared_error = -0.0\nsamples = 2\nvalue = 7.1'),
#  Text(0.9519650655021834, 0.4090909090909091, 'x[0] <= 1.086\nsquared_error = 0.273\nsamples = 7\nvalue = 5.929'),
#  Text(0.9432314410480349, 0.3181818181818182, 'x[3] <= 170.25\nsquared_error = 0.077\nsamples = 4\nvalue = 6.325'),
#  Text(0.9388646288209607, 0.22727272727272727, 'squared_error = 0.0\nsamples = 2\nvalue = 6.6'),
#  Text(0.9475982532751092, 0.22727272727272727, 'x[1] <= 86.05\nsquared_error = 0.003\nsamples = 2\nvalue = 6.05'),
#  Text(0.9432314410480349, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.1'),
#  Text(0.9519650655021834, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(0.9606986899563319, 0.3181818181818182, 'x[0] <= 1.087\nsquared_error = 0.047\nsamples = 3\nvalue = 5.4'),
#  Text(0.9563318777292577, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 5.7'),
#  Text(0.9650655021834061, 0.22727272727272727, 'x[4] <= 92.0\nsquared_error = 0.003\nsamples = 2\nvalue = 5.25'),
#  Text(0.9606986899563319, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 5.2'),
#  Text(0.9694323144104804, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 5.3'),
#  Text(0.9868995633187773, 0.5, 'x[1] <= 69.9\nsquared_error = 2.254\nsamples = 5\nvalue = 2.92'),
#  Text(0.982532751091703, 0.4090909090909091, 'squared_error = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(0.9912663755458515, 0.4090909090909091, 'x[0] <= 1.092\nsquared_error = 0.152\nsamples = 4\nvalue = 3.65'),
#  Text(0.9868995633187773, 0.3181818181818182, 'x[2] <= 90.55\nsquared_error = 0.016\nsamples = 3\nvalue = 3.867'),
#  Text(0.982532751091703, 0.22727272727272727, 'x[3] <= 131.875\nsquared_error = 0.002\nsamples = 2\nvalue = 3.95'),
#  Text(0.9781659388646288, 0.13636363636363635, 'squared_error = 0.0\nsamples = 1\nvalue = 4.0'),
#  Text(0.9868995633187773, 0.13636363636363635, 'squared_error = -0.0\nsamples = 1\nvalue = 3.9'),
#  Text(0.9912663755458515, 0.22727272727272727, 'squared_error = 0.0\nsamples = 1\nvalue = 3.7'),
#  Text(0.9956331877729258, 0.3181818181818182, 'squared_error = -0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.9716157205240175, 0.5909090909090909, 'squared_error = -0.0\nsamples = 1\nvalue = 17.4')]

# %%
path = reg.cost_complexity_pruning_path(X_train,y_train)
ccp_alpha = path.ccp_alphas

# %%
len(ccp_alpha)
# Out:
# 157

# %%
alphalist = []
for i in range(len(ccp_alpha)):  
    reg = DecisionTreeRegressor(ccp_alpha=ccp_alpha[i])  
    reg.fit(X_train, y_train)
    alphalist.append(reg)

# %%
alphalist[1:5]
# Out:
# [DecisionTreeRegressor(ccp_alpha=2.828030789094926e-16),
#  DecisionTreeRegressor(ccp_alpha=1.1312123156379704e-15),
#  DecisionTreeRegressor(ccp_alpha=1.6968184734569556e-15),
#  DecisionTreeRegressor(ccp_alpha=2.262424631275941e-15)]

# %%
trainscore = [alphalist[i].score(X_train, y_train) for i in range(len(alphalist))]
testscore = [alphalist[i].score(X_test, y_test) for i in range(len(alphalist))]
plt.xlabel('alpha')
plt.ylabel('accuracy')
plt.plot(ccp_alpha,trainscore,marker = 'o',label = 'training',color = 'magenta',drawstyle = 'steps-post')
plt.plot(ccp_alpha,testscore,marker = '+',label = 'testing',color = 'red',drawstyle = 'steps-post')
plt.legend()
plt.show()

# %%
clf = DecisionTreeRegressor(ccp_alpha=1)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(f'Decision Tree Normal Approach : {metrics.r2_score(y_test,y_pred)}')

rf = RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(X_train,y_train)
y_pred_rf = rf.predict(X_test)
print(f'Random Forest Normal Approach : {metrics.r2_score(y_test,y_pred_rf)}')
# Out:
# Decision Tree Normal Approach : 0.8891828524220972
# Random Forest Normal Approach : 0.9358983720312251

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV

params = {
    'RandomForest': {
        'model': RandomForestRegressor(),
        'params': {
            'n_estimators': [int(x) for x in np.linspace(start=1, stop=1200, num=10)],
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'max_depth': [int(x) for x in np.linspace(start=1, stop=30, num=5)],
            'min_samples_split': [2, 5, 10, 12],
            'min_samples_leaf': [2, 5, 10, 12],
            'max_features': ['sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        }
    },
    'D-tree': {
        'model': DecisionTreeRegressor(),
        'params': {
            'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
            'splitter': ['best', 'random'],
            'min_samples_split': [2, 5, 10, 12],
            'min_samples_leaf': [2, 5, 10, 12],
            'max_features': ['sqrt'],
            'ccp_alpha': [1, 2, 2.5, 3, 3.5, 4, 5],
        }
    },
    'SVM': {
        'model': SVR(),
        'params': {
            'C': [0.25, 0.50, 0.75, 1.0],
            'tol': [1e-10, 1e-5, 1e-4, 0.025, 0.050, 0.075],
            'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
            'max_iter': [int(x) for x in np.linspace(start=1, stop=250, num=10)],
        }
    }
}

scores = []

for model_name, mp in params.items():
    clf = RandomizedSearchCV(mp['model'], param_distributions=mp['params'], cv=5, n_jobs=-1, n_iter=10, scoring='neg_mean_squared_error')
    clf.fit(X_train, y_train)
    scores.append({
        'model_name': model_name,
        'best_score': clf.best_score_,
        'best_estimator': clf.best_estimator_
    })

scoresdf = pd.DataFrame(scores, columns=['model_name', 'best_score', 'best_estimator'])

scoresdf
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=250).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
#      model_name  best_score                                     best_estimator
# 0  RandomForest   -5.626272  (DecisionTreeRegressor(ccp_alpha=1, max_depth=...
# 1        D-tree  -11.623146  DecisionTreeRegressor(ccp_alpha=1, max_feature...
# 2           SVM  -25.484053  SVR(C=0.75, kernel='poly', max_iter=250, tol=0...

# %%
scoresdf = pd.DataFrame(scores, columns=['model_name', 'best_score', 'best_estimator'])
scoresdf
# Out:
#      model_name  best_score                                     best_estimator
# 0  RandomForest   -5.626272  (DecisionTreeRegressor(ccp_alpha=1, max_depth=...
# 1        D-tree  -11.623146  DecisionTreeRegressor(ccp_alpha=1, max_feature...
# 2           SVM  -25.484053  SVR(C=0.75, kernel='poly', max_iter=250, tol=0...

# %%
scores[0]['best_estimator']
# Out:
# RandomForestRegressor(ccp_alpha=1, max_depth=30, max_features='sqrt',
#                       min_samples_leaf=2, min_samples_split=12,
#                       n_estimators=400)

# %%
rf = RandomForestRegressor(n_estimators=1000,ccp_alpha=1)
rf.fit(X_train,y_train)

y_pred = rf.predict(X_test)

print(metrics.r2_score(y_test,y_pred))
# Out:
# 0.9360747936679319

# %%
totrainlist = np.array(totrain)
predicted = []
for i in range(len(totrainlist)):
    predicted.append(rf.predict([totrainlist[i]]))

totrain['Actual Result'] = test
totrain['Predicted Result'] = np.array(predicted)
totrain
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# D:\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#      Density  Abdomen  Chest  Weight    Hip  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1  154.25   94.5           12.3         12.602135
# 1     1.0853     83.0   93.6  173.25   98.7            6.1          7.469776
# 2     1.0414     87.9   95.8  154.00   99.2           25.3         25.171472
# 3     1.0751     86.4  101.8  184.75  101.2           10.4          9.368987
# 4     1.0340    100.0   97.3  184.25  101.9           28.7         30.146397
# ..       ...      ...    ...     ...    ...            ...               ...
# 247   1.0736     83.6   89.2  134.25   88.8           11.0          9.548090
# 248   1.0236    105.0  108.5  201.00  104.5           33.6         31.896739
# 249   1.0328    111.5  111.1  186.75  101.7           29.3         30.403794
# 250   1.0399    101.3  108.3  190.75   97.8           26.0         25.376357
# 251   1.0271    108.5  112.4  207.50  107.1           31.9         31.513300
#
# [252 rows x 7 columns]

# %%
totrain=totrain.drop(['Actual Result','Predicted Result'],axis=1)
totrain
# Out:
#      Density  Abdomen  Chest  Weight    Hip
# 0     1.0708     85.2   93.1  154.25   94.5
# 1     1.0853     83.0   93.6  173.25   98.7
# 2     1.0414     87.9   95.8  154.00   99.2
# 3     1.0751     86.4  101.8  184.75  101.2
# 4     1.0340    100.0   97.3  184.25  101.9
# ..       ...      ...    ...     ...    ...
# 247   1.0736     83.6   89.2  134.25   88.8
# 248   1.0236    105.0  108.5  201.00  104.5
# 249   1.0328    111.5  111.1  186.75  101.7
# 250   1.0399    101.3  108.3  190.75   97.8
# 251   1.0271    108.5  112.4  207.50  107.1
#
# [252 rows x 5 columns]

# %%
totrain
# Out:
#      Density  Abdomen  Chest  Weight    Hip  Actual Result  Predicted Result
# 0     1.0708     85.2   93.1  154.25   94.5           12.3         12.461782
# 1     1.0853     83.0   93.6  173.25   98.7            6.1          9.077653
# 2     1.0414     87.9   95.8  154.00   99.2           25.3         22.611304
# 3     1.0751     86.4  101.8  184.75  101.2           10.4         11.183840
# 4     1.0340    100.0   97.3  184.25  101.9           28.7         27.431931
# ..       ...      ...    ...     ...    ...            ...               ...
# 247   1.0736     83.6   89.2  134.25   88.8           11.0         10.095557
# 248   1.0236    105.0  108.5  201.00  104.5           33.6         30.277095
# 249   1.0328    111.5  111.1  186.75  101.7           29.3         29.339121
# 250   1.0399    101.3  108.3  190.75   97.8           26.0         25.704433
# 251   1.0271    108.5  112.4  207.50  107.1           31.9         30.257723
#
# [252 rows x 7 columns]

# %%
sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
sn.distplot(totrain['Predicted Result'],label='Predicted Result',hist=False,color='red')
plt.legend()
plt.plot()
# Out:
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\1504357722.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Actual Result'],label='Actual Result',hist=False,color='magenta')
# C:\Users\matheus.davin\AppData\Local\Temp\ipykernel_12076\1504357722.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(totrain['Predicted Result'],label='Predicted Result',hist=False,color='red')
# []

# %%
import pickle
file = open('bodyfatmodel1.pkl','wb')
pickle.dump(rf,file)
file.close
# Out:
# <function BufferedWriter.close()>
